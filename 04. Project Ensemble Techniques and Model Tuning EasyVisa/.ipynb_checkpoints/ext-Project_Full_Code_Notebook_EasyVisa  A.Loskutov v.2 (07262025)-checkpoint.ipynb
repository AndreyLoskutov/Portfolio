# %% [markdown]
# <center><p float="center">
#   <img src="https://upload.wikimedia.org/wikipedia/commons/e/e9/4_RGB_McCombs_School_Brand_Branded.png" width="300" height="100"/>
#   <img src="https://mma.prnewswire.com/media/1458111/Great_Learning_Logo.jpg?p=facebook" width="200" height="100"/>
# </p></center>
#
# <center><font size=10>Data Science and Business Analytics</font></center>
# <center><font size=6>Ensemble Techniques and Model Tuning</font></center>

# %% [markdown]
# <center><img src="https://images.pexels.com/photos/7235894/pexels-photo-7235894.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=2" width="800" height="500"></center>
#
# <center><font size=6>Visa Approval Facilitation</font></center>

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Context

# %% [markdown]
# Business communities in the United States are facing high demand for human resources, but one of the constant challenges is identifying and attracting the right talent, which is perhaps the most important element in remaining competitive. Companies in the United States look for hard-working, talented, and qualified individuals both locally as well as abroad.
#
# The Immigration and Nationality Act (INA) of the US permits foreign workers to come to the United States to work on either a temporary or permanent basis. The act also protects US workers against adverse impacts on their wages or working conditions by ensuring US employers' compliance with statutory requirements when they hire foreign workers to fill workforce shortages. The immigration programs are administered by the Office of Foreign Labor Certification (OFLC).
#
# OFLC processes job certification applications for employers seeking to bring foreign workers into the United States and grants certifications in those cases where employers can demonstrate that there are not sufficient US workers available to perform the work at wages that meet or exceed the wage paid for the occupation in the area of intended employment.

# %% [markdown]
# ## Objective

# %% [markdown]
# In FY 2016, the OFLC processed 775,979 employer applications for 1,699,957 positions for temporary and permanent labor certifications. This was a nine percent increase in the overall number of processed applications from the previous year. The process of reviewing every case is becoming a tedious task as the number of applicants is increasing every year.
#
# The increasing number of applicants every year calls for a Machine Learning based solution that can help in shortlisting the candidates having higher chances of VISA approval. OFLC has hired the firm EasyVisa for data-driven solutions. You as a data  scientist at EasyVisa have to analyze the data provided and, with the help of a classification model:
#
# * Facilitate the process of visa approvals.
# * Recommend a suitable profile for the applicants for whom the visa should be certified or denied based on the drivers that significantly influence the case status.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data contains the different attributes of employee and the employer. The detailed data dictionary is given below.
#
# * case_id: ID of each visa application
# * continent: Information of continent the employee
# * education_of_employee: Information of education of the employee
# * has_job_experience: Does the employee has any job experience? Y= Yes; N = No
# * requires_job_training: Does the employee require any job training? Y = Yes; N = No
# * no_of_employees: Number of employees in the employer's company
# * yr_of_estab: Year in which the employer's company was established
# * region_of_employment: Information of foreign worker's intended region of employment in the US.
# * prevailing_wage:  Average wage paid to similarly employed workers in a specific occupation in the area of intended employment. The purpose of the prevailing wage is to ensure that the foreign worker is not underpaid compared to other workers offering the same or similar service in the same area of employment.
# * unit_of_wage: Unit of prevailing wage. Values include Hourly, Weekly, Monthly, and Yearly.
# * full_time_position: Is the position of work full-time? Y = Full Time Position; N = Part Time Position
# * case_status:  Flag indicating if the Visa was certified or denied

# %% [markdown]
# ## Note: This is a sample solution for the project. Projects will NOT be graded on the basis of how well the submission matches this sample solution. Projects will be graded on the basis of the rubric only.

# %% [markdown]
# # **Importing necessary libraries**

# %%
# Installing the libraries with the specified version.
#!pip install numpy==1.25.2 pandas==1.5.3 scikit-learn==1.2.2 matplotlib==3.7.1 seaborn==0.13.1 xgboost==2.0.3 -q --user

# %%
# !pip install xgboost

# %%
# !pip install catboost lightgbm

# %% [markdown]
# **Note**: *After running the above cell, kindly restart the notebook kernel and run all cells sequentially from the start again.*

# %%
import warnings

warnings.filterwarnings("ignore")

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Library to split data
from sklearn.model_selection import train_test_split

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from catboost import CatBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics

# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 100)

# To oversample and undersample data
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# Libraries different ensemble classifiers
# Libraries for different ensemble classifiers
from sklearn.ensemble import (
    BaggingClassifier,
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier,
    StackingClassifier,
)

from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Libraries to get different metric scores
from sklearn import metrics
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)

# To tune different models
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # **Loading the dataset**

# %%
data = pd.read_csv("EasyVisa.csv")


'''from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Austin/06. Ensemble Techniques and Model Tuning/!2.7 Project Ensemble Techniques and Model Tuning EasyVisa/EasyVisa.csv'
data = pd.read_csv(file_path)'''
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')\nfile_path = '/content/drive/MyDrive/Austin/06. Ensemble Techniques and Model Tuning/!2.7 Project Ensemble Techniques and Model Tuning EasyVisa/EasyVisa.csv'\ndata = pd.read_csv(file_path)"

# %%
# copying data to another varaible to avoid any changes to original data
df = data.copy()

# %% [markdown]
# # **Overview of the Dataset**

# %% [markdown]
# * Observations
#
# * Sanity checks

# %% [markdown]
# ### View the first and last 5 rows of the dataset.

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# ### Understand the shape of the dataset.

# %%
df.shape
# Out:
# (25480, 12)

# %% [markdown]
# The dataset has 25480 rows and 12 columns of data

# %% [markdown]
# ### Check the data types of the columns for the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Summary of the dataset.

# %%
df.describe(include="all")
# Out:
#        case_id continent education_of_employee has_job_experience  \
# count    25480     25480                 25480              25480
# unique   25480         6                     4                  2
# top     EZYV01      Asia            Bachelor's                  Y
# freq         1     16861                 10234              14802
# mean       NaN       NaN                   NaN                NaN
# std        NaN       NaN                   NaN                NaN
# min        NaN       NaN                   NaN                NaN
# 25%        NaN       NaN                   NaN                NaN
# 50%        NaN       NaN                   NaN                NaN
# 75%        NaN       NaN                   NaN                NaN
# max        NaN       NaN                   NaN                NaN
#
#        requires_job_training  no_of_employees   yr_of_estab  \
# count                  25480     25480.000000  25480.000000
# ...

# %% [markdown]
# ### Observations

# %% [markdown]
# 1. **Unique Cases**
#    - Each record represents a unique case, as `case_id` has 25,480 unique values.
#
# 2. **Geographic Distribution**
#    - The majority of employees are from **Asia** (16,861 out of 25,480 cases), indicating strong representation from this continent.
#
# 3. **Education Background**
#    - The most common education level is **Bachelor's degree**, representing around 40% of the total dataset.
#
# 4. **Job Experience and Training Requirements**
#    - A significant number of applicants **have prior job experience** (`Y` = 14,802).
#    - Most job roles **do not require job training** (`N` = 22,525), suggesting they are intended for experienced candidates.
#
# 5. **Employment Type**
#    - The vast majority of positions are **full-time** (`Y` = 22,773).
#    - **Yearly wage** is the most common wage unit, used in 22,962 cases.
#
# 6. **Case Outcome**
#    - About **two-thirds of the cases were certified** (`Certified` = 17,018), indicating a high approval rate.
#
# 7. **Numerical Variables**
#    - `no_of_employees` has a wide range (from -26 to over 600,000). The **negative value suggests data quality issues**.
#    - `yr_of_estab` ranges from **1800 to 2016**. Dates before the 1900s may be **inaccurate or misentered**.
#    - `prevailing_wage` varies greatly, with a **high standard deviation**, indicating wage disparity across roles or industries.
#
# 8. **Regional Employment**
#    - The most common region of employment is the **Northeast** (7,195 cases), suggesting job concentration in that area.

# %%
# checking for unique values in case_id column
df["case_id"].nunique()
# Out:
# 25480

# %% [markdown]
# * Since all the values in Booking_ID column are unique we can drop it

# %%
df.drop(["case_id"], axis=1, inplace=True)

# %% [markdown]
# ### Check for missing values

# %%
df.isnull().sum()
# Out:
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# * There are no missing values in the dataset

# %% [markdown]
# Check negative values of no_of_employees

# %%
df.loc[df["no_of_employees"] < 0].shape
# Out:
# (33, 11)

# %% [markdown]
# Drop data with negative values of no_of_employees becuase there are only 33

# %%
df = df.loc[df["no_of_employees"] >= 0]

# %% [markdown]
# # <a name='link2'>**Exploratory Data Analysis (EDA)**</a>

# %% [markdown]
# - EDA is an important part of any project involving data.
# - It is important to investigate and understand the data better before building a model with it.
# - A few questions have been mentioned below which will help you approach the analysis in the right manner and generate insights from the data.
# - A thorough analysis of the data, in addition to the questions mentioned below, should be done.

# %% [markdown]
# **Leading Questions**
#
# What is the distribution of visa case statuses (certified vs. denied)?
#
#
# 1. What is the distribution of visa case statuses (certified vs. denied)?
# 2. How does the education level of employees impact visa approval rates?
# 3. Is there a significant difference in visa approval rates between employees with and without prior job experience?
# 4. How does the prevailing wage affect visa approval? Do higher wages lead to higher chances of approval?
# 5. Do certain regions in the US have higher visa approval rates compared to others?
# 6. How does the number of employees in a company influence visa approval? Do larger companies have a higher approval rate?
# 7. Are visa approval rates different across various continents of employees? Which continent has the highest and lowest approval rates?

# %%
# function to create labeled barplots
def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 2, 6))
    else:
        plt.figure(figsize=(n + 2, 6))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n],
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
# function to plot stacked bar chart
def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 5, 6))
    plt.legend(
        loc="lower left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
def histogram_boxplot(data, feature, figsize=(15, 10), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (15,10))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a triangle will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
### function to plot distributions wrt target


def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
        stat="density",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
        stat="density",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# #### Observations on continent

# %%
labeled_barplot(df, "continent", perc=True)

# %% [markdown]
# - The dataset is **highly imbalanced** in terms of continent representation.
# - **Asia** dominates the data, accounting for **66.2%** of all cases.
# - **Europe** and **North America** follow with **14.6%** and **12.9%**, respectively.
# - **South America (3.3%)**, **Africa (2.2%)**, and **Oceania (0.8%)** are **minimally represented**.
# - This skewed distribution may introduce **geographical bias** in model training and should be addressed during analysis or modeling.

# %% [markdown]
# #### Observations on education_of_employee

# %%
labeled_barplot(df, "education_of_employee", perc=True)

# %% [markdown]
# - The dataset is predominantly composed of employees with **Bachelor's degrees (40.2%)** and **Master's degrees (37.8%)**.
# - Together, these two categories account for nearly **78% of the total cases**, indicating a highly educated workforce.
# - **High School** graduates make up **13.4%** of the data, showing a smaller but notable segment of less formally educated workers.
# - **Doctorate holders** represent the smallest group at **8.6%**.
# - The data indicates that the job market in this dataset is primarily geared toward candidates with **undergraduate or postgraduate qualifications**.

# %% [markdown]
# #### Observations on has_job_experience

# %%
labeled_barplot(df, "has_job_experience", perc=True)

# %% [markdown]
# - A majority of the individuals in the dataset **have prior job experience**.
# - **58.1%** of the applicants reported having job experience (`Y`), while **41.9%** reported having none (`N`).
# - This indicates that the dataset is slightly skewed toward **experienced candidates**, which may influence the outcomes of job-related analyses or models.
# - Depending on the use case, it may be valuable to examine how experience impacts wage levels or case approval status.

# %% [markdown]
# #### Observations on requires_job_training

# %%
labeled_barplot(df, "requires_job_training", perc=True)

# %% [markdown]
# - The vast majority of positions in the dataset **do not require job training**.
# - **88.4%** of cases are marked as `N` (no training required), while only **11.6%** require training (`Y`).
# - This suggests that most job roles are likely intended for candidates who are already equipped with the necessary skills.
# - The imbalance may indicate that training-intensive roles are relatively rare or reserved for specialized positions.
# - This feature could be a strong indicator of job complexity or wage expectations.

# %% [markdown]
# #### Observations on yr_of_estab

# %%
histogram_boxplot(df, "yr_of_estab")

# %% [markdown]
# - The majority of companies in the dataset were established **after 1980**, with a significant concentration from the **1990s to early 2000s**.
# - A **long tail of older establishments** extends back to the **1800s**, with some entries even before 1850.
# - The **boxplot shows a wide range with many outliers**, particularly on the earlier end (pre-1950).
# - These early years may represent **data entry errors or special historical cases**, especially entries prior to 1900.
# - Data cleanup may be required to handle **outliers or improbable establishment years** for better model reliability.
# - The distribution suggests that most businesses represented are **modern, possibly tech-focused or post-industrial**.

# %% [markdown]
# #### Observations on region_of_employment

# %%
labeled_barplot(df, "region_of_employment", perc=True)

# %% [markdown]
# - The distribution of employment across U.S. regions is **relatively balanced** among the top three:
#   - **Northeast**: 28.3%
#   - **South**: 27.5%
#   - **West**: 25.8%
# - These three regions collectively account for over **81%** of the dataset.
# - **Midwest** follows with 16.9%, showing moderate representation.
# - **Island regions** (likely U.S. territories such as Puerto Rico or Guam) have a **very small presence** at 1.5%.
# - This distribution indicates that most employment opportunities in the dataset are concentrated in the **continental U.S.**, especially in the **Northeast, South, and West**.

# %% [markdown]
# #### Observations on prevailing_wage

# %%
histogram_boxplot(df, "prevailing_wage")

# %% [markdown]
# #### Observations on unit_of_wage

# %%
labeled_barplot(df, "unit_of_wage", perc=True)

# %% [markdown]
# - The vast majority of wage records are reported on a **Yearly basis (90.1%)**, indicating that annual salaries are the standard in this dataset.
# - **Hourly wages** account for **8.5%**, which may represent part-time or hourly contract roles.
# - **Weekly (1.1%)** and **Monthly (0.3%)** units are **rare**, making them minor components of the overall dataset.
# - This skewed distribution suggests that any wage standardization or comparison across records should consider converting all values to a **common unit**, preferably annual.
# - It's important to normalize wages before analysis, especially if using wage as a feature in modeling.

# %% [markdown]
# #### Observations on full_time_position

# %%
labeled_barplot(df, "full_time_position", perc=True)

# %% [markdown]
# - The majority of roles in the dataset are **full-time positions**, accounting for **89.4%** of all records.
# - Only **10.6%** of the cases are for **part-time or non-full-time roles**.
# - This indicates a **strong preference or demand for full-time employment** in the dataset.
# - Analysis involving working hours, benefits, or wage expectations should account for this imbalance.
# - If comparing job types or outcomes, it may be helpful to treat full-time vs. part-time as a significant categorical variable.

# %% [markdown]
# #### Observations on case_status

# %%
labeled_barplot(df, "case_status", perc=True)

# %% [markdown]
# - Approximately **66.8%** of the applications in the dataset are **Certified**, indicating a relatively high approval rate.
# - **33.2%** of the cases are **Denied**, representing a substantial portion of the datasetion.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ### continent vs case_status

# %%
stacked_barplot(df, "continent", "case_status")
# Out:
# case_status    Certified  Denied    All
# continent
# All                17001    8446  25447
# Asia               11001    5839  16840
# North America       2037    1250   3287
# Europe              2953     774   3727
# South America        492     359    851
# Africa               396     154    550
# Oceania              122      70    192
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - The overall certification rate is approximately **66.8%**, but it **varies by continent**:
#   - **Europe** has the **highest certification rate** (~79%) among all continents.
#   - **Africa** also shows a **strong approval rate** (~72%).
#   - **Asia** and **Oceania** follow with certification rates of approximately **66% and 64%**, respectively.
#   - **North America** and **South America** have the **lowest certification rates**, around **62% and 58%**.
#
# - While **Asia** has the highest number of total cases, the approval rate is **close to the global average**.
#
# - This suggests that **region of origin may influence case outcomes**, possibly due to varying applicant profiles, employer practices, or systemic factors.
#
# - These patterns may warrant further investigation into how **continent-specific features** (e.g., education, experience, job roles) relate to approval likelihood.

# %% [markdown]
# ### education_of_employee vs case_status

# %%
stacked_barplot(df, "education_of_employee", "case_status")
# Out:
# case_status            Certified  Denied    All
# education_of_employee
# All                        17001    8446  25447
# Bachelor's                  6362    3858  10220
# High School                 1164    2252   3416
# Master's                    7565    2057   9622
# Doctorate                   1910     279   2189
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  ### requires_job_training VS case_status_time_position       0

# %%
stacked_barplot(df, "requires_job_training", "case_status")
# Out:
# case_status            Certified  Denied    All
# requires_job_training
# All                        17001    8446  25447
# N                          15000    7498  22498
# Y                           2001     948   2949
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - The certification rates are **very similar** for both groups:
#   - **Applicants not requiring job training (`N`)**: ~66.7% certified
#   - **Applicants requiring job training (`Y`)**: ~67.9% certified
#
# - Despite assumptions that training needs might affect case outcomes, the data shows **no significant difference** in approval likelihood based on this variable alone.
#
# - Breakdown of total cases:
#   - `N`: 22,498 cases (15,000 certified, 7,498 denied)
#   - `Y`: 2,949 cases (2,001 certified, 948 denied)
#
# - The **proportion of certifications remains stable**, regardless of job training requirement.
#
# - While this feature may not be a strong individual predictor, it could still be **useful in interaction with other variables** (e.g., experience or education level).

# %% [markdown]
# - The **likelihood of case certification increases with the level of education**.
# - **Doctorate holders** have the **highest certification rate** (~87%), followed by:
#   - **Master’s degree** holders (~79%)
#   - **Bachelor’s degree** holders (~62%)
#   - **High School** graduates have the **lowest approval rate**, with only ~34% of cases certified.
#
# - The **denial rate is highest among High School graduates**, making up nearly two-thirds of that group.
#
# - This trend highlights a **strong positive correlation between educational attainment and case approval**.
#
# - It suggests that higher education may be a significant factor in decision-making, possibly due to perceived skill level, job type, or wage thresholds.
#
# - These insights may inform feature importance in predictive modeling or guide policy discussions around visa eligibility and qualifications.

# %% [markdown]
# ### has_job_experience", "case_status

# %%
stacked_barplot(df, "has_job_experience", "case_status")
# Out:
# case_status         Certified  Denied    All
# has_job_experience
# All                     17001    8446  25447
# N                        5986    4675  10661
# Y                       11015    3771  14786
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Candidates **with prior job experience (`Y`)** have a noticeably **higher certification rate (~74%)** compared to those **without experience (`N`)**, who are certified at a rate of only **56%**.
# - Among the 25,447 total records:
#   - **Experienced candidates**: 11,015 certified, 3,771 denied
#   - **Inexperienced candidates**: 5,986 certified, 4,675 denied
#
# - The denial rate is **significantly higher** among applicants with no prior job experience.
#
# - This suggests that **job experience is an important factor** influencing case outcomes and may be a key feature in predictive modeling.
#
# - Incorporating this variable could improve model accuracy for predicting certification likelihood.

# %% [markdown]
# ### region_of_employment VS case_status

# %%
stacked_barplot(df, "region_of_employment", "case_status")
# Out:
# case_status           Certified  Denied    All
# region_of_employment
# All                       17001    8446  25447
# Northeast                  4524    2665   7189
# West                       4097    2481   6578
# South                      4908    2098   7006
# Midwest                    3246    1053   4299
# Island                      226     149    375
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  The **Midwest** has the **highest approval rate**, followed by the **South**, indicating potentially favorable conditions for certification in these regions.
# - The **West**, **Northeast**, and **Island** regions show **lower approval rates**, with the Island region having the **highest denial rate** (~40%).
# - These trends may reflect differences in **job types, employer practices, or local labor market factors**.
#
# - Region-specific features may enhance model predictions when included in training data.

# %% [markdown]
# ### unit_of_wage VS case_status

# %%
stacked_barplot(df, "unit_of_wage", "case_status")
# Out:
# case_status   Certified  Denied    All
# unit_of_wage
# All               17001    8446  25447
# Year              16030    6903  22933
# Hour                747    1406   2153
# Week                169     103    272
# Month                55      34     89
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - **Yearly wage** cases have the **highest certification rate (~71%)**, likely reflecting salaried, full-time professional roles.
# - **Hourly wage** positions are much more likely to be denied, with a **denial rate of ~65%**.
# - **Weekly and monthly wage** units show intermediate certification rates but are far less common in the dataset.
#
# - These trends indicate that **higher stability and predictability (e.g., yearly wages)** may be associated with higher approval rates.
# - Including `unit_of_wage` as a feature could improve model performance, especially when paired with normalized wage values.

# %% [markdown]
# ### full_time_position VS case_status

# %%
stacked_barplot(df, "full_time_position", "case_status")
# Out:
# case_status         Certified  Denied    All
# full_time_position
# All                     17001    8446  25447
# Y                       15146    7595  22741
# N                        1855     851   2706
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - The dataset shows a strong preference for **full-time positions**    |
#
# - Interestingly, the **certification rate for non-full-time positions is slightly higher**, despite being a much smaller subset (2,706 vs. 22,741 records).
# - This suggests that while full-time roles dominate the dataset, **being full-time does not guarantee a higher approval rate**.
# - The reason behind this might be influenced by other features such as wage, job role, or education level.
#
# - Full-time status remains a relevant feature and may **interact with other variables** to impact case outcomes.

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(df.corr(numeric_only = True), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %%
sns.pairplot(data=df, diag_kind="kde")
plt.show()

# %% [markdown]
# ### no_of_employees VS case_status

# %%
distribution_plot_wrt_target(df, "no_of_employees", "case_status")

# %% [markdown]
# - The correlation matrix reveals **very weak linear relationships** among the three numeric features:
#   `no_of_employees`, `yr_of_estab`, and `prevailing_wage`.
#
# - Key correlation values:
#   - `no_of_employees` vs. `yr_of_estab`: **-0.02** (negligible negative correlation)
#   - `no_of_employees` vs. `prevailing_wage`: **-0.01** (no meaningful relationship)
#   - `yr_of_estab` vs. `prevailing_wage`: **0.01** (also negligible)
#
# - All correlation values are extremely close to **zero**, suggesting that these variables are **not linearly correlated**.
#
# - This implies that:
#   - Multicollinearity is **not a concern** among these variables.
#   - **Non-linear models** may be more effective in capturing interactions, if any exist.
#
# - These features can still be valuable for prediction but may require transformation or interaction terms to improve performance in linear models.

# %% [markdown]
# ### yr_of_estab VS case_status

# %%
distribution_plot_wrt_target(df, "yr_of_estab", "case_status")

# %% [markdown]
# - The **distribution plots** show that:
#   - Both **Certified** and **Denied** applications are predominantly associated with companies established after **1980**.
#   - Certified cases have a slightly higher density around the **1990s and early 2000s**, suggesting a trend toward newer companies receiving more certifications.
#
# - The **boxplots (with and without outliers)** confirm:
#   - The median establishment year for both Certified and Denied cases is close, but slightly **newer for Certified cases**.
#   - Denied cases show a **broader spread** and include **more older companies (pre-1950)**, some of which may be data anomalies or outliers.
#
# - Overall, while there is **no strong difference** between the two groups, **Certified applications slightly lean toward newer companies**.
# - This subtle pattern might be useful in modeling when combined with other features (e.g., company size or wage).

# %% [markdown]
# ### prevailing_wage VS case_status

# %%
distribution_plot_wrt_target(df, "prevailing_wage", "case_status")

# %% [markdown]
# - **Distribution plots** indicate:
#   - Denied cases are concentrated more heavily at the **lower end of the wage spectrum**, especially below **$40,000**.
#   - Certified cases have a **higher average prevailing wage**, with density peaking closer to **$70,000–$90,000**.
#
# - **Boxplots (with and without outliers)** show:
#   - The **median prevailing wage** is **higher for Certified cases** than for Denied cases.
#   - Denied applications exhibit more cases with **very low wages**, which could negatively influence the likelihood of approval.
#   - Both distributions are right-skewed with numerous **high-end outliers**.
#
# - This analysis suggests that **higher wages are associated with a greater chance of certification**.
# - Prevailing wage may be a **strong predictor** in classification models for `case_status`.
#
# - It may be useful to apply **log transformation** or **binning** to handle skewness and outliers before modeling.

# %% [markdown]
# ### What is the distribution of visa case statuses (certified vs. denied)?rates?

# %%
labeled_barplot(df, "case_status", perc=True)

# %% [markdown]
# - Approximately **66.8%** of the applications in the dataset are **Certified**, indicating a relatively high approval rate.
# - **33.2%** of the cases are **Denied**, representing a substantial portion of the dataset.

# %% [markdown]
# ### How does the education level of employees impact visa approval rates?

# %%
stacked_barplot(df, "education_of_employee", "case_status")
# Out:
# case_status            Certified  Denied    All
# education_of_employee
# All                        17001    8446  25447
# Bachelor's                  6362    3858  10220
# High School                 1164    2252   3416
# Master's                    7565    2057   9622
# Doctorate                   1910     279   2189
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Applicants with only a **high school education have the lowest approval rate**, with **two-thirds of their applications denied**.
# - In contrast, **Master’s and Doctorate holders enjoy much higher approval rates**, suggesting a strong link between **education level and visa approval success**.
# - This trend is consistent and shows that **education is a powerful predictor** of certification outcomes in employment-based visa applicationnce.

# %% [markdown]
# ### Is there a significant difference in visa approval rates between employees with and without prior job experience?

# %%
stacked_barplot(df, "has_job_experience", "case_status")
# Out:
# case_status         Certified  Denied    All
# has_job_experience
# All                     17001    8446  25447
# N                        5986    4675  10661
# Y                       11015    3771  14786
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Among the 25,447 applications:
#   - Applicants **with experience (`Y`)**: 11,015 certified out of 14,786 total
#   - Applicants **without experience (`N`)**: 5,986 certified out of 10,661 total
#
# - This clearly shows that **prior job experience significantly improves visa approval rates**.
# - The difference in certification proportions indicates that **experience is a strong predictor** of a successful outcome and should be considered a **key feature in modeling or policy analysis**.

# %% [markdown]
# ### How does the prevailing wage affect visa approval? Do higher wages lead to higher chances of approval?

# %%
distribution_plot_wrt_target(df, "prevailing_wage", "case_status")

# %% [markdown]
# - **Yes — higher prevailing wages are associated with higher visa approval rates.**
#
# ### Key Observations:
#
# - **Distribution Plots:**
#   - Denied cases are more concentrated around **lower wages**, especially under **$50,000**.
#   - Certified cases tend to have **higher wages**, peaking around **$70,000–$90,000**, with a broader spread toward higher values.
#
# - **Boxplots:**
#   - Median wage is **visibly higher** for Certified applications than Denied ones.
#   - Certified cases show a wider and more right-skewed distribution — consistent with higher-paying roles being more likely to be approved.
#   - Even after removing outliers, the difference in **central tendency remains**, reinforcing the trend.
#
# ### Implications:
# - **Prevailing wage is a strong predictor** of case outcome and should be considered a critical feature in predictive models.
# - Applicants in **higher-paying positions** are more likely to have their cases certified, possibly reflecting job skill requirements or employer sponsorship credibility.
# - **Normalization or log transformation** of wages may help in modeling due to the skewed distribution.

# %% [markdown]
# ### Do certain regions in the US have higher visa approval rates compared to others?

# %%
stacked_barplot(df, "region_of_employment", "case_status")
# Out:
# case_status           Certified  Denied    All
# region_of_employment
# All                       17001    8446  25447
# Northeast                  4524    2665   7189
# West                       4097    2481   6578
# South                      4908    2098   7006
# Midwest                    3246    1053   4299
# Island                      226     149    375
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#      |
#
# ### Key Insights:
# - The **Midwest** leads in approval rate (~75.5%), followed by the **South**, suggesting favorable conditions or case characteristics in these regions.
# - **Island**, **West**, and **Northeast** regions show **lower certification rates**, potentially due to regional job types, employer profiles, or wage structures.
# - Although differences are moderate, they are consistent and may reflect **region-specific trends** in job quality or visa policy indictive modeling.

# %% [markdown]
# ### How does the number of employees in a company influence visa approval? Do larger companies have a higher approval rate?

# %%
distribution_plot_wrt_target(df, "no_of_employees", "case_status")

# %% [markdown]
# - Both **Certified** and **Denied** applications are **heavily right-skewed**, with most companies having **fewer than 10,000 employees**.
# - A few extremely large companies (up to ~600,000 employees) act as **outliers**, but the bulk of the data lies in the **1,000–5,000 range**
# - When outliers are excluded, the **median company size appears slightly higher for Certified cases** than Denied ones.
# - However, the difference is **not very pronounced**, suggesting that **company size alone is not a strong standalone predictor** of visa approval.
# - Larger companies may have **better approval processes or compliance**, but small to mid-size employers also get approvals..s.

# %%
# Step 1: Define bins from 0 to 10,000 with step 1,000, plus an extra bin for >10,000
bins = list(range(0, 11_000, 1000)) + [np.inf]  # Adds an extra bin for >10,000
labels = [f'{bins[i]}-{int(bins[i+1])}' if bins[i+1] != np.inf else '10000+' for i in range(len(bins)-1)]

# Step 2: Bin the data
df['employee_bin'] = pd.cut(df['no_of_employees'], bins=bins, labels=labels, right=False)

# Step 3: Create pivot table
bin_counts = df.pivot_table(index='employee_bin', columns='case_status', aggfunc='size', fill_value=0)

# Step 4: Add row-wise totals
bin_counts['Total'] = bin_counts.sum(axis=1)

# Step 5: Add column-wise totals
total_row = pd.DataFrame(bin_counts.sum(axis=0)).T
total_row.index = ['Total']
bin_counts = pd.concat([bin_counts, total_row])

# Display final result
print(bin_counts)
# Out:
# case_status  Certified  Denied  Total
# 0-1000            4087    2115   6202
# 1000-2000         3877    2036   5913
# 2000-3000         3332    1648   4980
# 3000-4000         2343    1210   3553
# 4000-5000         1501     658   2159
# 5000-6000          649     246    895
# 6000-7000          142      38    180
# 7000-8000           31      13     44
# 8000-9000           26      15     41
# 9000-10000          30      14     44
# 10000+             983     453   1436
# Total            17001    8446  25447

# %%
# Step 3: Group data
bin_counts = df.pivot_table(index='employee_bin', columns='case_status', aggfunc='size', fill_value=0)

# Step 4: Plot histogram
bin_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='tab20')

# Step 5: Style the plot
plt.title('Distribution of No. of Employees by Case Status')
plt.xlabel('Number of Employees (Binned)')
plt.ylabel('Number of Records')
plt.xticks(rotation=45)
plt.legend(title='Case Status')
plt.tight_layout()

# Show plot
plt.show()

# %%
large_companies = df[df['no_of_employees'] > 10_000]

# Смотрим распределение по ключевым признакам
features_to_explore = ['continent', 'education_of_employee', 'case_status', 
                       'has_job_experience', 'requires_job_training', 'region_of_employment']

for feature in features_to_explore:
    print(f"\n--- {feature.upper()} ---")
    print(large_companies[feature].value_counts(dropna=False))
# Out:
# --- CONTINENT ---
# continent
# Asia             894
# Europe           226
# North America    220
# South America     47
# Africa            36
# Oceania           13
# Name: count, dtype: int64
#
# --- EDUCATION_OF_EMPLOYEE ---
# education_of_employee
# Master's       604
# Bachelor's     521
# High School    181
# Doctorate      130
# Name: count, dtype: int64
#
# --- CASE_STATUS ---
# case_status
# Certified    983
# Denied       453
# Name: count, dtype: int64
#
# --- HAS_JOB_EXPERIENCE ---
# has_job_experience
# Y    846
# N    590
# Name: count, dtype: int64
#
# --- REQUIRES_JOB_TRAINING ---
# requires_job_training
# N    1250
# Y     186
# Name: count, dtype: int64
#
# --- REGION_OF_EMPLOYMENT ---
# region_of_employment
# Northeast    410
# South        393
# West         389
# Midwest      205
# Island        39
# Name: count, dtype: int64

# %%
large_companies = df[df['no_of_employees'] > 10_000]

features_to_plot = [
    'continent',
    'education_of_employee',
    'case_status',
    'has_job_experience',
    'requires_job_training',
    'region_of_employment',
    'unit_of_wage',
    'full_time_position'
]

for feature in features_to_plot:
    plt.figure(figsize=(8, 4))
    large_companies[feature].value_counts(dropna=False).plot(kind='bar', color='cornflowerblue')
    plt.title(f'Distribution of {feature} (Employees > 10K)')
    plt.xlabel(feature)
    plt.ylabel('Number of Records')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
df.drop(["employee_bin"], axis=1, inplace=True)

# %% [markdown]
# ### Are visa approval rates different across various continents of employees? Which continent has the highest and lowest approval rates?

# %%
stacked_barplot(df, "continent", "case_status")
# Out:
# case_status    Certified  Denied    All
# continent
# All                17001    8446  25447
# Asia               11001    5839  16840
# North America       2037    1250   3287
# Europe              2953     774   3727
# South America        492     359    851
# Africa               396     154    550
# Oceania              122      70    192
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  **Europe** has the **highest visa approval rate (~79%)**, suggesting strong applicant profiles or favorable processing trends.
# - **South America** has the **lowest approval rate (~58%)**, followed by North America.
# - **Asia**, while accounting for the majority of applications, holds a **moderate approval rate (~65%)**.
# - **Africa and Oceania**, despite smaller sample sizes, show relatively **high approval rates**.

# %% [markdown]
# # **Data Pre-processing**

# %% [markdown]
# - Missing value treatment (if needed)
# - Feature engineering (if needed)
# - Outlier detection and treatment (if needed)
# - Preparing data for modeling
# - Any other preprocessing steps (if needed)

# %% [markdown]
# #### Missing value treatment (if needed)

# %%
df.isnull().sum()
# Out:
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# #### Outlier detection and treatment

# %%
numerical_col = df.select_dtypes(include=np.number).columns.tolist()
plt.figure(figsize=(20, 30))

for i, variable in enumerate(numerical_col):
    plt.subplot(5, 4, i + 1)
    plt.boxplot(df[variable], whis=1.5)
    plt.tight_layout()
    plt.title(variable)

plt.show()

# %% [markdown]
# ### Feature engineering

# %%
df.shape
# Out:
# (25447, 11)

# %%
# 1. Remove invalid values: zero or negative employee counts
df = df[df['no_of_employees'] > 0].copy()

# 2. Cap extreme values to reduce skew (capping at 100,000)
df['no_of_employees_capped'] = np.clip(df['no_of_employees'], a_min=1, a_max=100_000)

# 3. Log-transform the employee count (good for skewed features)
df['log_employees'] = np.log1p(df['no_of_employees_capped'])  # log(1 + x)

# 4. Bin employee counts into interpretable categorical ranges
bins = list(range(0, 11_000, 1000)) + [25_000, 50_000, 100_000, np.inf]
labels = [
    '0–1k', '1k–2k', '2k–3k', '3k–4k', '4k–5k', '5k–6k', '6k–7k', '7k–8k', '8k–9k', '9k–10k',
    '10k–25k', '25k–50k', '50k–100k', '100k+'
]
df['employee_bin'] = pd.cut(df['no_of_employees_capped'], bins=bins, labels=labels, right=False)

# %%
df.shape
# Out:
# (25447, 14)

# %%
df.head()
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 0      Asia           High School                  N                     N
# 1      Asia              Master's                  Y                     N
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status  no_of_employees_capped  \
# ...

# %%
df['log_wage'] = np.log1p(df['prevailing_wage'])

# %%
df['company_age'] = 2025 - df['yr_of_estab']

# %%
df.shape
# Out:
# (25447, 16)

# %%
df.head()
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 0      Asia           High School                  N                     N
# 1      Asia              Master's                  Y                     N
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status  no_of_employees_capped  \
# ...

# %%
# Make a copy of the dataset
data1 = df.copy()

# %%
data1.drop(["yr_of_estab"], axis=1, inplace=True)

# %% [markdown]
# ### Preparing data for modeling

# %%
# Copy full dataframe, then modify target
data1 = data1.copy()
data1['case_status'] = data1['case_status'].map({'Denied': 0, 'Certified': 1})  # Convert target to binary

# %%
#  One-hot encode all categorical columns
categorical_cols = data1.select_dtypes(include=['object', 'category']).columns.tolist()
df_encoded = pd.get_dummies(data1, columns=categorical_cols, drop_first=True)

# %%
categorical_cols
# Out:
# ['continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'employee_bin']

# %%
# Step 3: Define features and target
X = df_encoded.drop(columns='case_status')
y = df_encoded['case_status']

# Step 4: Split into train/val/test (60/20/20)
from sklearn.model_selection import train_test_split

X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=1
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=1
)

# Check shapes
print("Train shape:", X_train.shape)
print("Validation shape:", X_val.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (15267, 37)
# Validation shape: (5090, 37)
# Test shape: (5090, 37)

# %%
X_train.head()
# Out:
#        no_of_employees  prevailing_wage  no_of_employees_capped  \
# 13421             2711         86707.20                    2711
# 7213              4515         20136.52                    4515
# 5833              2804         61488.43                    2804
# 4404              4298         50834.53                    4298
# 1041               962         25041.81                     962
#
#        log_employees   log_wage  company_age  continent_Asia  \
# 13421       7.905442  11.370304           22            True
# 7213        8.415382   9.910340           55            True
# 5833        7.939159  11.026621          186           False
# 4404        8.366138  10.836351           32            True
# 1041        6.870053  10.128342          153            True
#
#        continent_Europe  continent_North America  continent_Oceania  \
# 13421             False                    False              False
# 7213              False                    False              False
# ...

# %%
X_train = X_train.astype(int)
X_val = X_val.astype(int)
X_test = X_test.astype(int)

# %%
X_train.head()
# Out:
#        no_of_employees  prevailing_wage  no_of_employees_capped  \
# 13421             2711            86707                    2711
# 7213              4515            20136                    4515
# 5833              2804            61488                    2804
# 4404              4298            50834                    4298
# 1041               962            25041                     962
#
#        log_employees  log_wage  company_age  continent_Asia  continent_Europe  \
# 13421              7        11           22               1                 0
# 7213               8         9           55               1                 0
# 5833               7        11          186               0                 1
# 4404               8        10           32               1                 0
# 1041               6        10          153               1                 0
#
#        continent_North America  continent_Oceania  continent_South America  \
# ...

# %%
X_train.shape
# Out:
# (15267, 37)

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## Model evaluation criterion

# %% [markdown]
# **Model can make wrong predictions as**:
#
# 1. Model predicts that the visa application will get certified but in reality, the visa application should get denied.
# 2. Model predicts that the visa application will not get certified but in reality, the visa application should get certified.
#
# **Which case is more important?**
# * Both the cases are important as:
#
# * If a visa is certified when it had to be denied a wrong employee will get the job position while US citizens will miss the opportunity to work on that position.
#
# * If a visa is denied when it had to be certified the U.S. will lose a suitable human resource that can contribute to the economy.
#
#
# **How to reduce the losses?**
#
# * `F1 Score` can be used a the metric for evaluation of the model, greater the F1  score higher are the chances of minimizing False Negatives and False Positives.
# * We will use balanced class weights so that model focuses equally on both classes.

# %%
# defining a function to compute different metrics to check performance of a classification model built using sklearn
def model_performance_classification_sklearn(model, predictors, target):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred)  # to compute Recall
    precision = precision_score(target, pred)  # to compute Precision
    f1 = f1_score(target, pred)  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {"Accuracy": acc, "Recall": recall, "Precision": precision, "F1": f1,},
        index=[0],
    )

    return df_perf

# %%
def confusion_matrix_sklearn(model, predictors, target):
    """
    To plot the confusion_matrix with percentages

    model: classifier
    predictors: independent variables
    target: dependent variable
    """
    y_pred = model.predict(predictors)
    cm = confusion_matrix(target, y_pred)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(2, 2)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ## Initial Model Building

# %% [markdown]
# ### Model Building - Original Data

# %% [markdown]
# ### Intro to KFold Cross Validation:
#
# 1. **Definition**:
# - K-Fold Cross-Validation is a resampling technique used to evaluate the performance of a machine learning model. It splits the dataset into K subsets (folds), trains the model on K-1 folds, and tests it on the remaining fold. This process is repeated K times, with each fold used as the test set exactly once. The final performance is the average of the evaluation metric (e.g., accuracy, recall, etc.) across all folds.
#
# 2. **Why We Use K-Fold Cross-Validation:**
# - Robust Performance Estimation: It provides a better estimate of a model’s performance by using all data points for both training and testing (but not at the same time).
# - Reduces Overfitting: Unlike a single train-test split, K-Fold Cross-Validation ensures the model is tested on multiple unseen subsets of data, reducing the chance of overfitting to a specific dataset split.
# - Maximizes Data Usage: It uses all data for training and testing at different stages, making it ideal for small datasets where splitting once may not be sufficient.
#
# 4. **Analogy 1:**
#
# - Context: Imagine you're preparing for a big exam. Instead of solving one full-length practice test, you divide the syllabus into K topics. Each time, you study K-1 topics and take a mini-test on the remaining topic. You repeat this process until you've tested yourself on every topic. Finally, you average your scores across all tests to determine how well-prepared you are.
#
# - K topics = K folds.
# - Studying K-1 topics = Training the model on K-1 folds.
# - Testing on the remaining topic = Testing the model on the remaining fold.
#
# - By the end of this process, you have a clear idea of your strengths and weaknesses across the entire syllabus, just like K-Fold Cross-Validation gives a clear picture of the model's performance across the dataset.
#
#
# 5. **Analogy 2:**
# - Context: Sports Team Practice. Imagine you're coaching a sports team, and you want to prepare them for a big game. Instead of having everyone practice together all the time, you divide the team into K groups and follow this process:
#
# - You let K-1 groups practice together (this is your training phase).
# - The remaining group plays a practice match against the others to test their skills (this is your testing phase).
# - Rotate the groups, so each group gets a chance to be the test group once.
# - By the end, every group has been tested, and you've identified strengths and weaknesses across the entire team.
#
#
#
# 6. **Key Takeaways:**
# - K-Fold Cross-Validation ensures the model is rigorously tested on all parts of the data.
# - It prevents biased evaluations and increases confidence in a model's ability to generalize.

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import make_scorer, f1_score

# Define F1 scorer
f1_scorer = make_scorer(f1_score)

# List of models to evaluate
models = [
    ("Bagging", BaggingClassifier(random_state=1)),
    ("Random forest", RandomForestClassifier(random_state=1)),
    ("GBM", GradientBoostingClassifier(random_state=1)),
    ("Adaboost", AdaBoostClassifier(random_state=1)),
    ("DTree", DecisionTreeClassifier(random_state=1)),
    ("LGBM", LGBMClassifier(random_state=1, verbose=-1)),
    ("CatBoost", CatBoostClassifier(random_state=1, verbose=0)),
]

# === Cross-Validation on Training Set ===
print("\nCross-Validation performance on training dataset (F1-score):\n")

for name, model in models:
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    f1_cv = cross_val_score(model, X_train, y_train, scoring=f1_scorer, cv=kfold)
    print(f"{name}: F1 = {f1_cv.mean():.4f}")

# === Evaluation on Validation Set ===
print("\nValidation Performance (F1-score):\n")

for name, model in models:
    model.fit(X_train, y_train)
    y_pred_val = model.predict(X_val)
    val_f1 = f1_score(y_val, y_pred_val)
    print(f"{name}: F1 = {val_f1:.4f}")
# Out:
# Cross-Validation performance on training dataset (F1-score):
#
# Bagging: F1 = 0.7689
# Random forest: F1 = 0.8028
# GBM: F1 = 0.8225
# Adaboost: F1 = 0.8149
# DTree: F1 = 0.7462
# LGBM: F1 = 0.8185
# CatBoost: F1 = 0.8185
#
# Validation Performance (F1-score):
#
# Bagging: F1 = 0.7815
# Random forest: F1 = 0.8015
# GBM: F1 = 0.8261
# Adaboost: F1 = 0.8196
# DTree: F1 = 0.7449
# LGBM: F1 = 0.8202
# CatBoost: F1 = 0.8190

# %%
print("\nTraining and Validation Performance Difference:\n")

for name, model in models:
    model.fit(X_train, y_train)
    scores_train = f1_score(y_train, model.predict(X_train))
    scores_val = f1_score(y_val, model.predict(X_val))
    difference1 = scores_train - scores_val
    print("{}: Training Score: {:.4f}, Validation Score: {:.4f}, Difference: {:.4f}".format(name, scores_train, scores_val, difference1))
# Out:
# Training and Validation Performance Difference:
#
# Bagging: Training Score: 0.9886, Validation Score: 0.7815, Difference: 0.2072
# Random forest: Training Score: 1.0000, Validation Score: 0.8015, Difference: 0.1985
# GBM: Training Score: 0.8276, Validation Score: 0.8261, Difference: 0.0015
# Adaboost: Training Score: 0.8192, Validation Score: 0.8196, Difference: -0.0004
# DTree: Training Score: 1.0000, Validation Score: 0.7449, Difference: 0.2551
# LGBM: Training Score: 0.8453, Validation Score: 0.8202, Difference: 0.0251
# CatBoost: Training Score: 0.8545, Validation Score: 0.8190, Difference: 0.0356

# %% [markdown]
# - GBM has the best performance (0.8261)

# %% [markdown]
# ### Model Building - Oversampled Data

# %% [markdown]
# ## Oversampling in Machine Learning
#
# ### **Definition**
# Oversampling is a technique used in machine learning to address class imbalance in classification problems. It involves increasing the number of instances in the minority class by duplicating existing samples or generating synthetic samples, so that both classes are better represented in the dataset.
#
# ---
#
# ### **Why We Use Oversampling**
# In imbalanced datasets, machine learning models tend to be biased toward the majority class. This can lead to poor performance when predicting the minority class, especially in metrics like recall, precision, or F1-score. Oversampling helps correct this bias.
#
# ---
#
# ### **What It Is Used For**
# - **Binary classification** problems with a significant class imbalance (e.g., fraud detection, disease diagnosis)
# - **Multiclass problems** where one or more classes are underrepresented
# - When improving the model's **ability to detect rare events** is more important than overall accuracy
#
# ---
#
# ### **How It’s Helpful**
# - Improves model **generalization** to the minority class
# - Increases **recall** and **F1-score** for minority classes
# - Reduces the likelihood that the model will ignore rare but important classes
# - Helps in **training stable models** with more balanced decision boundaries
#
# ---
#
# ### **Common Oversampling Techniques**
# - **Random Oversampling:** Simply duplicates random samples from the minority class.
# - **SMOTE (Synthetic Minority Over-sampling Technique):** Generates new, synthetic examples by interpolating between existing minority class instances.
# - **ADASYN:** An extension of SMOTE that focuses on difficult-to-learn examples.
#
# ---
#
# ### **What Is SMOTE?**
# SMOTE (Synthetic Minority Over-sampling Technique) is one of the most widely used oversampling methods. Instead of duplicating existing samples, SMOTE creates new synthetic data points by selecting a sample from the minority class and introducing new samples along the line segments joining that sample and its k-nearest minority class neighbors. This process increases the diversity of the minority class and helps the model learn a more general decision boundary. SMOTE is especially useful because it avoids the risk of overfitting that often occurs with simple duplication, and it helps balance the dataset in a more realistic way by enriching the feature space with new, interpolated examples.
#
# ---
#
# ### **How Are Synthetic Samples Not Fake?**
# Synthetic samples are not "fake" in the sense of being random or unrelated to the actual data. Instead, they are systematically generated from real data points using mathematical interpolation. For example, SMOTE creates new points by calculating values that lie between existing minority class samples in the feature space. These new samples preserve the structure, distribution, and relationships present in the real data, allowing the model to learn patterns more effectively. While synthetic, they are grounded in actual data and represent plausible variations that the model could encounter in the real world.

# %%
print("Before Oversampling, counts of label 'Yes': {}".format(sum(y_train == 1)))
print("Before Oversampling, counts of label 'No': {} \n".format(sum(y_train == 0)))

# Purpose:
# This code applies SMOTE (Synthetic Minority Over-sampling Technique) to address class imbalance
# by generating synthetic samples for the minority class. It does so by interpolating between existing
# minority class samples and their nearest neighbors.

from imblearn.over_sampling import SMOTE

# 1. Define your oversampling technique:
sm = SMOTE(
    sampling_strategy=1,     # Balance the classes so that minority and majority have equal numbers (1:1 ratio)
    k_neighbors=5,           # For each minority sample, SMOTE selects 5 nearest neighbors from the same class
    random_state=1           # Seed for reproducibility
)  # Synthetic Minority Over-sampling Technique

# Apply SMOTE to the training data only (never apply to validation or test sets)
X_train_over, y_train_over = sm.fit_resample(X_train, y_train)

# What is k_neighbors=5?
# For each minority class instance, SMOTE finds its 5 nearest neighbors using Euclidean distance.
# Then, it randomly selects one of those 5 neighbors and creates a synthetic sample along the line
# connecting the original point and the neighbor. This process is repeated until the desired class
# balance is achieved. k_neighbors=5 is the default and a common choice to ensure diversity in synthetic samples.

print("After Oversampling, counts of label 'Yes': {}".format(sum(y_train_over == 1)))
print("After Oversampling, counts of label 'No': {} \n".format(sum(y_train_over == 0)))


print("After Oversampling, the shape of train_X: {}".format(X_train_over.shape))
print("After Oversampling, the shape of train_y: {} \n".format(y_train_over.shape))
# Out:
# Before Oversampling, counts of label 'Yes': 10199
# Before Oversampling, counts of label 'No': 5068
#
# After Oversampling, counts of label 'Yes': 10199
# After Oversampling, counts of label 'No': 10199
#
# After Oversampling, the shape of train_X: (20398, 37)
# After Oversampling, the shape of train_y: (20398,)

# %%
# Initialize the list of models
models = []  # Empty list to store all the models

# Append models to the list
models.append(("Bagging", BaggingClassifier(
    estimator=DecisionTreeClassifier(random_state=1, class_weight='balanced'), random_state=1)))
models.append(("Random forest", RandomForestClassifier(random_state=1, class_weight='balanced')))
models.append(("GBM", GradientBoostingClassifier(random_state=1)))
models.append(("Adaboost", AdaBoostClassifier(random_state=1)))
models.append(("dtree", DecisionTreeClassifier(random_state=1, class_weight='balanced')))
models.append(("LGBM", LGBMClassifier(random_state=1, verbose=-1)))  # LightGBM
models.append(("CatBoost", CatBoostClassifier(random_state=1, verbose=0)))  # CatBoost

# Evaluate training performance using F1-score
print("\nTraining Performance (F1-score):\n")
for name, model in models:
    model.fit(X_train_over, y_train_over)
    scores = f1_score(y_train_over, model.predict(X_train_over))
    print(f"{name}: {scores:.4f}")

# Evaluate validation performance using F1-score
print("\nValidation Performance (F1-score):\n")
for name, model in models:
    model.fit(X_train_over, y_train_over)
    scores = f1_score(y_val, model.predict(X_val))
    print(f"{name}: {scores:.4f}")
# Out:
# Training Performance (F1-score):
#
# Bagging: 0.9866
# Random forest: 1.0000
# GBM: 0.8051
# Adaboost: 0.7793
# dtree: 1.0000
# LGBM: 0.8264
# CatBoost: 0.8443
#
# Validation Performance (F1-score):
#
# Bagging: 0.7656
# Random forest: 0.7929
# GBM: 0.8075
# Adaboost: 0.7866
# dtree: 0.7326
# LGBM: 0.8092
# CatBoost: 0.8090

# %%
print("\nTraining and Validation Performance Difference (F1-score):\n")

for name, model in models:
    model.fit(X_train_over, y_train_over)
    scores_train = f1_score(y_train_over, model.predict(X_train_over))
    scores_val = f1_score(y_val, model.predict(X_val))
    difference = scores_train - scores_val
    print(f"{name}: Training Score: {scores_train:.4f}, Validation Score: {scores_val:.4f}, Difference: {difference:.4f}")
# Out:
# Training and Validation Performance Difference (F1-score):
#
# Bagging: Training Score: 0.9866, Validation Score: 0.7656, Difference: 0.2211
# Random forest: Training Score: 1.0000, Validation Score: 0.7929, Difference: 0.2071
# GBM: Training Score: 0.8051, Validation Score: 0.8075, Difference: -0.0024
# Adaboost: Training Score: 0.7793, Validation Score: 0.7866, Difference: -0.0072
# dtree: Training Score: 1.0000, Validation Score: 0.7326, Difference: 0.2674
# LGBM: Training Score: 0.8264, Validation Score: 0.8092, Difference: 0.0172
# CatBoost: Training Score: 0.8443, Validation Score: 0.8090, Difference: 0.0353

# %% [markdown]
# LGBM has the best performance on validation

# %% [markdown]
# ### Model Building - Undersampled Data

# %% [markdown]
# ## Undersampling in Machine Learning
#
# ### **Definition**
# Undersampling is a technique used to handle class imbalance in machine learning by reducing the number of samples in the majority class. This is done to create a more balanced dataset, which can help the model learn to recognize patterns in both classes more fairly.
#
# ---
#
# ### **Why We Use Undersampling**
# In highly imbalanced datasets, models tend to favor the majority class, often misclassifying minority class examples. Undersampling reduces this bias by balancing the class distribution, allowing the model to pay more attention to the minority class. It’s particularly useful when the dataset is large and computational efficiency is a concern.
#
# ---
#
# ### **What It Is Used For**
# - **Binary classification** problems where the majority class overwhelms the minority class (e.g., spam detection, credit default)
# - When we have a **large dataset** and want to reduce training time
# - When preserving all majority class data is not critical, and some loss of information is acceptable
#
# ---
#
# ### **How It’s Helpful**
# - Helps the model **focus equally** on both classes
# - Reduces **training time** and **computational cost** by trimming the dataset size
# - Improves **recall and precision** for the minority class in some cases
# - Avoids **overfitting** to the majority class
#
# ---
#
# ### **Common Undersampling Techniques**
# - **Random Undersampling:** Randomly removes samples from the majority class.
# - **Tomek Links:** Identifies and removes borderline majority class instances that are close to minority class examples.
# - **NearMiss:** Selects majority class samples that are closest to minority class instances, keeping only the most informative ones.
#
# ---
#
# ### **What Is RandomUnderSampler?**
# RandomUnderSampler is a basic and widely used undersampling technique provided by libraries such as `imbalanced-learn`. It works by randomly selecting a subset of the majority class so that it matches the size of the minority class. This straightforward approach is efficient and easy to apply, especially when the dataset is large and can afford to lose some examples. Although it may discard potentially useful data, RandomUnderSampler is useful when training speed is important or when models are severely overfitting due to class imbalance. It is often used as a baseline before trying more advanced undersampling techniques.
#
# ---
#
# ### **How Is Reduced Data Still Useful?**
# Even though undersampling removes some data, the remaining majority class samples are often sufficient for the model to learn general patterns, especially when the dataset is initially large. The key idea is that **reducing quantity does not necessarily mean losing quality**—the algorithm still sees enough diversity in the majority class to build accurate decision boundaries. Additionally, careful selection techniques like NearMiss ensure that only the most informative samples are retained, making the reduced dataset both smaller and more efficient for learning.

# %%
rus = RandomUnderSampler(random_state=1)
X_train_un, y_train_un = rus.fit_resample(X_train, y_train)

# %%
print("Before Under Sampling, counts of label 'Yes': {}".format(sum(y_train == 1)))
print("Before Under Sampling, counts of label 'No': {} \n".format(sum(y_train == 0)))

print("After Under Sampling, counts of label 'Yes': {}".format(sum(y_train_un == 1)))
print("After Under Sampling, counts of label 'No': {} \n".format(sum(y_train_un == 0)))

print("After Under Sampling, the shape of train_X: {}".format(X_train_un.shape))
print("After Under Sampling, the shape of train_y: {} \n".format(y_train_un.shape))
# Out:
# Before Under Sampling, counts of label 'Yes': 10199
# Before Under Sampling, counts of label 'No': 5068
#
# After Under Sampling, counts of label 'Yes': 5068
# After Under Sampling, counts of label 'No': 5068
#
# After Under Sampling, the shape of train_X: (10136, 37)
# After Under Sampling, the shape of train_y: (10136,)

# %%
models = []  # List to store all classifiers

# Append models
models.append(("Bagging", BaggingClassifier(estimator=DecisionTreeClassifier(random_state=1, class_weight='balanced'), random_state=1)))
models.append(("Random forest", RandomForestClassifier(random_state=1, class_weight='balanced')))
models.append(("GBM", GradientBoostingClassifier(random_state=1)))
models.append(("Adaboost", AdaBoostClassifier(random_state=1)))
models.append(("dtree", DecisionTreeClassifier(random_state=1, class_weight='balanced')))
models.append(("LGBM", LGBMClassifier(random_state=1, verbose=-1)))
models.append(("CatBoost", CatBoostClassifier(random_state=1, verbose=0)))

print("\nTraining Performance (F1-score):\n")
for name, model in models:
    model.fit(X_train_un, y_train_un)
    score_train = f1_score(y_train_un, model.predict(X_train_un))
    print(f"{name}: {score_train:.4f}")

print("\nValidation Performance (F1-score):\n")
for name, model in models:
    model.fit(X_train_un, y_train_un)
    score_val = f1_score(y_val, model.predict(X_val))
    print(f"{name}: {score_val:.4f}")
# Out:
# Training Performance (F1-score):
#
# Bagging: 0.9808
# Random forest: 1.0000
# GBM: 0.7289
# Adaboost: 0.7037
# dtree: 1.0000
# LGBM: 0.7802
# CatBoost: 0.7869
#
# Validation Performance (F1-score):
#
# Bagging: 0.7022
# Random forest: 0.7363
# GBM: 0.7693
# Adaboost: 0.7646
# dtree: 0.6937
# LGBM: 0.7621
# CatBoost: 0.7615

# %%
print("\nTraining and Validation Performance Difference (F1-score):\n")

for name, model in models:
    model.fit(X_train_un, y_train_un)
    scores_train = f1_score(y_train_un, model.predict(X_train_un))
    scores_val = f1_score(y_val, model.predict(X_val))
    difference = scores_train - scores_val
    print(f"{name}: Training Score: {scores_train:.4f}, Validation Score: {scores_val:.4f}, Difference: {difference:.4f}")
# Out:
# Training and Validation Performance Difference (F1-score):
#
# Bagging: Training Score: 0.9808, Validation Score: 0.7022, Difference: 0.2787
# Random forest: Training Score: 1.0000, Validation Score: 0.7363, Difference: 0.2637
# GBM: Training Score: 0.7289, Validation Score: 0.7693, Difference: -0.0404
# Adaboost: Training Score: 0.7037, Validation Score: 0.7646, Difference: -0.0610
# dtree: Training Score: 1.0000, Validation Score: 0.6937, Difference: 0.3063
# LGBM: Training Score: 0.7802, Validation Score: 0.7621, Difference: 0.0182
# CatBoost: Training Score: 0.7869, Validation Score: 0.7615, Difference: 0.0253

# %% [markdown]
# - GBM has the best performance

# %% [markdown]
# - After building 21 models, it was observed that both the GBM, Catboost and Adaboost models, trained on an undersampled dataset, as well as the GBM model trained on an oversampled dataset, exhibited strong performance on both the training and validation datasets.
# - Sometimes models might overfit after undersampling and oversampling, so it's better to tune the models to get a generalized performance
# - We will tune these 3 models using the same data (undersampled or oversampled) as we trained them on before

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# **### GridSearchCV vs. RandomizedSearchCV**
#
# | **Criteria**           | **GridSearchCV**                              | **RandomizedSearchCV**                       |
# |------------------------|-----------------------------------------------|----------------------------------------------|
# | **Search Method**      | Exhaustive search over specified parameter values. | Random search over a specified parameter distribution. |
# | **Parameter Space**    | Evaluates all possible combinations of parameters. | Evaluates a fixed number of random parameter combinations. |
# | **Execution Time**     | Generally longer due to exhaustive search, especially with large parameter spaces. | Generally shorter because it evaluates fewer combinations. |
# | **Computational Cost** | Higher, because it evaluates all combinations. | Lower, because it evaluates a subset of combinations. |
# | **Likelihood of Finding Optimal Parameters** | Higher if the parameter space is small, because all combinations are tested. | Depends on the number of iterations and the randomness of sampling; good for large parameter spaces. |
# | **Use Case Suitability** | Best for small to medium-sized parameter grids where exhaustive search is feasible. | Best for large parameter grids where exhaustive search is impractical. |
# | **Control Over Search** | Full control over the parameter combinations to be tested. | Less control; relies on random sampling. |
# | **Scalability**        | Less scalable with an increasing number of parameters or parameter values. | More scalable with an increasing number of parameters or parameter values. |
# | **Implementation Simplicity** | Simple but potentially requires more computing resources. | More complex but can be more efficient in terms of resource usage. |
# | **Parallel Processing** | Supports parallel processing to speed up the search. | Supports parallel processing to speed up the search. |

# %% [markdown]
# ### Tuning AdaBoostClassifier model with original data

# %%
# %%time
# 1. Defining model
Model = AdaBoostClassifier(random_state=1)


param_grid = {
    "n_estimators": np.arange(50,110,25),
    "learning_rate": [0.01,0.1,0.05],
    "estimator": [
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# 3. Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score)

#5. Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_jobs = -1, n_iter=50, scoring=scorer,
                             cv=5, # will do cross validation for u automatically
                             random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 75, 'learning_rate': 0.05, 'estimator': DecisionTreeClassifier(max_depth=3, random_state=1)} with CV score=0.8238154705996568:
# CPU times: total: 4.39 s
# Wall time: 2min 2s

# %%
# Instantiate the tuned AdaBoost model with best parameters from RandomizedSearchCV
tuned_adb = AdaBoostClassifier(
    random_state=1,
    n_estimators=75,
    learning_rate=0.05,
    estimator=DecisionTreeClassifier(max_depth=3, random_state=1)  # Use base_estimator instead of estimator
)

# Fit the model to training data
tuned_adb.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3,
#                                                     random_state=1),
#                    learning_rate=0.05, n_estimators=75, random_state=1)

# %% [markdown]
# ### Checking model performance on training set

# %%
# Checking model's performance on training set
adb_train = model_performance_classification_sklearn(tuned_adb, X_train, y_train)
adb_train
# Out:
#    Accuracy    Recall  Precision        F1
# 0   0.74684  0.900775    0.76304  0.826206

# %% [markdown]
# ### Checking model performance on validation set

# %%
# Checking model's performance on validation set
adb_val = model_performance_classification_sklearn(tuned_adb, X_val, y_val)
adb_val
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.744204  0.898853   0.761395  0.824434

# %% [markdown]
# ### Tuning AdaBoostClassifier model with oversampling data

# %%
# %%time
# 1. Defining model
Model = AdaBoostClassifier(random_state=1)


param_grid = {
    "n_estimators": np.arange(50,110,25),
    "learning_rate": [0.01,0.1,0.05],
    "estimator": [
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# 3. Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score)

#5. Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_jobs = -1, n_iter=50, scoring=scorer,
                             cv=5, # will do cross validation for u automatically
                             random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 100, 'learning_rate': 0.1, 'estimator': DecisionTreeClassifier(max_depth=3, random_state=1)} with CV score=0.7961001835766475:
# CPU times: total: 8.12 s
# Wall time: 2min 16s

# %%
# Instantiate the tuned AdaBoost model with best parameters from RandomizedSearchCV
tuned_adb_over = AdaBoostClassifier(
    random_state=1,
    n_estimators=100,
    learning_rate=0.1,
    estimator=DecisionTreeClassifier(max_depth=3, random_state=1)  # Use base_estimator instead of estimator
)

# Fit the model to training data
tuned_adb_over.fit(X_train_over, y_train_over)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3,
#                                                     random_state=1),
#                    learning_rate=0.1, n_estimators=100, random_state=1)

# %%
# Checking model's performance on training set
adb_train_over = model_performance_classification_sklearn(tuned_adb_over, X_train_over, y_train_over)
adb_train_over
# Out:
#    Accuracy    Recall  Precision        F1
# 0   0.79998  0.817629   0.789753  0.803449

# %% [markdown]
# ### Checking model performance on validation set

# %%
# Checking model's performance on validation set
adb_val_over = model_performance_classification_sklearn(tuned_adb_over, X_val, y_val)
adb_val_over
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.734381  0.812702   0.794481  0.803488

# %% [markdown]
# ### Tuning AdaBoostClassifier model with Undersampled data

# %%
# %%time
# 1. Defining model
Model = AdaBoostClassifier(random_state=1)


param_grid = {
    "n_estimators": np.arange(50,110,25),
    "learning_rate": [0.01,0.1,0.05],
    "estimator": [
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# 3. Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score)

#5. Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_jobs = -1, n_iter=50, scoring=scorer,
                             cv=5, # will do cross validation for u automatically
                             random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_un, y_train_un)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 75, 'learning_rate': 0.05, 'estimator': DecisionTreeClassifier(max_depth=3, random_state=1)} with CV score=0.7194732884137702:
# CPU times: total: 3.55 s
# Wall time: 1min 7s

# %%
# Instantiate the tuned AdaBoost model with best parameters from RandomizedSearchCV
tuned_adb_un = AdaBoostClassifier(
    random_state=1,
    n_estimators=75,
    learning_rate=0.05,
    estimator=DecisionTreeClassifier(max_depth=3, random_state=1)  # Use base_estimator instead of estimator
)

# Fit the model to training data
tuned_adb_un.fit(X_train_un, y_train_un)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3,
#                                                     random_state=1),
#                    learning_rate=0.05, n_estimators=75, random_state=1)

# %%
# Checking model's performance on training set
adb_train_un = model_performance_classification_sklearn(tuned_adb_un, X_train_un, y_train_un)
adb_train_un
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.711425  0.752565   0.695351  0.722828

# %% [markdown]
# ### Checking model performance on validation set

# %%
# Checking model's performance on validation set
adb_val_un = model_performance_classification_sklearn(tuned_adb_un, X_val, y_val)
adb_val_un
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.711984  0.743605   0.809798  0.775291

# %% [markdown]
# ### Tuning  Gradient Boosting model with original Data

# %%
# %%time

#Creating pipeline
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": np.arange(50,110,25),
    "learning_rate": [0.01,0.1,0.05],
    "subsample":[0.7,0.9],
    "max_features":[0.5,0.7,1],
}


# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score)

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train,y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.9, 'n_estimators': 75, 'max_features': 0.7, 'learning_rate': 0.05} with CV score=0.8246891660234639:
# CPU times: total: 6.17 s
# Wall time: 1min 56s

# %%
tuned_gbm1 = GradientBoostingClassifier(
    random_state=1,
    subsample=0.9,
    n_estimators=75,
    max_features=0.7,
    learning_rate=0.05,
    init=AdaBoostClassifier(random_state=1),
)
tuned_gbm1.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(init=AdaBoostClassifier(random_state=1),
#                            learning_rate=0.05, max_features=0.7,
#                            n_estimators=75, random_state=1, subsample=0.9)

# %% [markdown]
# ### Checking model performance on training set

# %%
# Checking model's performance on training set
gbm1_train = model_performance_classification_sklearn(
    tuned_gbm1, X_train, y_train
)
gbm1_train
# Out:
#    Accuracy    Recall  Precision        F1
# 0   0.74625  0.899206   0.763169  0.825621

# %% [markdown]
# ### Checking model performance on validation set

# %%
# Checking model's performance on validation set
gbm1_val = model_performance_classification_sklearn(tuned_gbm1, X_val, y_val)
gbm1_val
# Out:
#    Accuracy    Recall  Precision       F1
# 0  0.742633  0.898265   0.760139  0.82345

# %% [markdown]
# ### Tuning  Gradient Boosting model with oversampling Data

# %%
# %%time

#Creating pipeline
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": np.arange(50,110,25),
    "learning_rate": [0.01,0.1,0.05],
    "subsample":[0.7,0.9],
    "max_features":[0.5,0.7,1],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score)

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over,y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.7, 'n_estimators': 100, 'max_features': 0.7, 'learning_rate': 0.1} with CV score=0.7960415754817232:
# CPU times: total: 8.22 s
# Wall time: 2min 30s

# %%
tuned_gbm1_over = GradientBoostingClassifier(
    random_state=1,
    subsample=0.9,
    n_estimators=75,
    max_features=0.7,
    learning_rate=0.1,
    init=AdaBoostClassifier(random_state=1),
)
tuned_gbm1_over.fit(X_train_over, y_train_over)
# Out:
# GradientBoostingClassifier(init=AdaBoostClassifier(random_state=1),
#                            max_features=0.7, n_estimators=75, random_state=1,
#                            subsample=0.9)

# %% [markdown]
# ### Checking model performance on training set

# %%
# Checking model's performance on training set
gbm1_train_over = model_performance_classification_sklearn(
    tuned_gbm1_over, X_train_over, y_train_over
)
gbm1_train_over
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.796156  0.822434   0.781369  0.801376

# %% [markdown]
# ### Checking model performance on validation set

# %%
# Checking model's performance on validation set
gbm1_val_over = model_performance_classification_sklearn(tuned_gbm1_over, X_val, y_val)
gbm1_val_over
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.738507  0.822699   0.793534  0.807853

# %% [markdown]
# ### Tuning  Gradient Boosting model with undersampling Data

# %%
# %%time

#Creating pipeline
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": np.arange(50,110,25),
    "learning_rate": [0.01,0.1,0.05],
    "subsample":[0.7,0.9],
    "max_features":[0.5,0.7,1],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score)

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_un,y_train_un)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.9, 'n_estimators': 50, 'max_features': 0.5, 'learning_rate': 0.1} with CV score=0.7188725118707383:
# CPU times: total: 4.38 s
# Wall time: 1min 23s

# %%
tuned_gbm1_un = GradientBoostingClassifier(
    random_state=1,
    subsample=0.9,
    n_estimators=75,
    max_features=0.7,
    learning_rate=0.1),
)
tuned_gbm1_un.fit(X_train_un, y_train_un)
# Out:
# GradientBoostingClassifier(init=AdaBoostClassifier(random_state=1),
#                            max_features=0.7, n_estimators=75, random_state=1,
#                            subsample=0.9)

# %% [markdown]
# ### Checking model performance on training set

# %%
# Checking model's performance on training set
gbm1_train_un = model_performance_classification_sklearn(
    tuned_gbm1_un, X_train_un, y_train_un
)
gbm1_train_un
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.717837  0.742502   0.707597  0.724629

# %% [markdown]
# ### Checking model performance on validation set

# %%
# Checking model's performance on validation set
gbm1_val_un = model_performance_classification_sklearn(tuned_gbm1_un, X_val, y_val)
gbm1_val_un
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.707859  0.726845   0.815842  0.768776

# %% [markdown]
# ### Tuning Bagging Classifier model with original Data

# %%
# Define the base estimator
base_estimator = DecisionTreeClassifier(random_state=1)

# Define the BaggingClassifier (corrected keyword)
bagging_model = BaggingClassifier(estimator=base_estimator, random_state=1)

# Updated parameter grid
param_grid = {
    'max_samples': [0.8, 0.9, 1],
    'max_features': [0.7, 0.8, 0.9],
    'n_estimators': [30, 50, 70],
}

# Define F1 scorer
f1_scorer = metrics.make_scorer(metrics.f1_score)

# Set up GridSearchCV
grid_search = GridSearchCV(
    estimator=bagging_model,
    param_grid=param_grid,
    scoring=f1_scorer,
    cv=5,
    n_jobs=-1
)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Output the best results
print("Best parameters are:", grid_search.best_params_)
print("Best cross-validation F1 score: {:.4f}".format(grid_search.best_score_))
# Out:
# Best parameters are: {'max_features': 0.7, 'max_samples': 0.8, 'n_estimators': 70}
# Best cross-validation F1 score: 0.8100

# %%
base_estimator = DecisionTreeClassifier(random_state=1)
tuned_bagging = BaggingClassifier(
    estimator=base_estimator,
    n_estimators=70,
    max_samples=0.8,
    max_features=0.7,
    random_state=1
)

# Fit the model
tuned_bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(random_state=1),
#                   max_features=0.7, max_samples=0.8, n_estimators=70,
#                   random_state=1)

# %% [markdown]
# ### Checking model performance on training set

# %%
tuned_bagging_train_perf = model_performance_classification_sklearn(
    tuned_bagging, X_train, y_train
)

# Display the result
tuned_bagging_train_perf
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.999476  0.999804   0.999412  0.999608

# %% [markdown]
# ### Checking model performance on validation set

# %%
# Checking model's performance on validation set
tuned_bagging_val_perf = grid_search.best_estimator_

# Evaluate on validation set using model
bagging_val = model_performance_classification_sklearn( tuned_bagging_val_perf, X_val, y_val)
bagging_val
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.724754  0.877095   0.752143  0.809828

# %% [markdown]
# ### Tuning Random Forest model with original Data

# %%
# %%time

# 1. Define the model
tuned_rf = RandomForestClassifier(random_state=1, oob_score=True, bootstrap=True)

# 2. Define the parameter grid
param_grid = {
    "n_estimators": [50, 75, 100],
    "min_samples_leaf": np.arange(1, 4),
    "max_features": [0.3, 0.6, 0.1, 'sqrt'],
    "max_samples": np.arange(0.4, 0.8, 0.1)
}

# 3. Type of scoring used
acc_scorer = metrics.make_scorer(metrics.f1_score)

# 4. Grid search
grid_obj = GridSearchCV(tuned_rf, param_grid, scoring=acc_scorer, cv=5, n_jobs=-1)  # change to n_jobs=1 if parallel fails
grid_obj.fit(X_train, y_train)

# 5. Best estimator
tuned_rf = grid_obj.best_estimator_

# 6. Fit best model (optional if already fitted)
tuned_rf.fit(X_train, y_train)
# Out:
# CPU times: total: 15.7 s
# Wall time: 12min 46s
# RandomForestClassifier(max_samples=0.4, min_samples_leaf=3, oob_score=True,
#                        random_state=1)

# %%
tuned_rf = RandomForestClassifier(
    random_state=1,
    max_samples=0.4,
    min_samples_leaf=3,
    oob_score=True,
    n_estimators=100,      # You can adjust if you have a specific value
    max_features='sqrt'    # Or 0.7 if that's what you found best
)

tuned_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_samples=0.4, min_samples_leaf=3, oob_score=True,
#                        random_state=1)

# %% [markdown]
# ### Checking model performance on training set

# %%
# Confusion matrix
confusion_matrix_sklearn(tuned_rf, X_train, y_train)

# Metrics
tuned_rf_model_train_perf = model_performance_classification_sklearn(tuned_rf, X_train, y_train)
tuned_rf_model_train_perf
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.803039  0.919992   0.810696  0.861893

# %% [markdown]
# ### Checking model performance on validation set

# %%
# Validation set
confusion_matrix_sklearn(tuned_rf, X_val, y_val)
tuned_rf_model_val_perf = model_performance_classification_sklearn(tuned_rf, X_val, y_val)
tuned_rf_model_val_perf
# Out:
#    Accuracy    Recall  Precision       F1
# 0  0.744794  0.879447   0.770876  0.82159

# %% [markdown]
# ### Tuning Decision Trees model with original Data

# %%
# Define the model
dt_model = DecisionTreeClassifier(random_state=1)

# Define your custom parameter grid
param_grid = {
    'max_depth': np.arange(2, 6),
    'min_samples_leaf': [1, 4, 7],
    'max_leaf_nodes': [10, 15],
    'min_impurity_decrease': [0.0001, 0.001]
}

# Define F1 scorer
f1_scorer = metrics.make_scorer(metrics.f1_score)

# Set up GridSearchCV
grid_search = GridSearchCV(
    estimator=dt_model,
    param_grid=param_grid,
    scoring=f1_scorer,
    cv=5,
    n_jobs=-1
)

# Fit to the training data
grid_search.fit(X_train, y_train)

# Print best parameters and score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation F1 score: {:.4f}".format(grid_search.best_score_))

# Refit the model using best parameters
tuned_decision_tree = grid_search.best_estimator_
tuned_decision_tree.fit(X_train, y_train)
# Out:
# Best parameters: {'max_depth': 5, 'max_leaf_nodes': 15, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 1}
# Best cross-validation F1 score: 0.8222
# DecisionTreeClassifier(max_depth=5, max_leaf_nodes=15,
#                        min_impurity_decrease=0.0001, random_state=1)

# %%
tuned_decision_tree = DecisionTreeClassifier(
    max_depth=5,
    max_leaf_nodes=15,
    min_impurity_decrease=0.0001,
    min_samples_leaf=1,
    random_state=1
)
tuned_decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_leaf_nodes=15,
#                        min_impurity_decrease=0.0001, random_state=1)

# %% [markdown]
# #### Checking model performance on training set

# %%
confusion_matrix_sklearn(tuned_decision_tree, X_train, y_train)
dt_train_perf = model_performance_classification_sklearn(tuned_decision_tree, X_train, y_train)
print("Train Performance:")
print(dt_train_perf)
# Out:
# Train Performance:
#    Accuracy    Recall  Precision        F1
# 0  0.737145  0.915874   0.747519  0.823177

# %% [markdown]
# #### Checking model performance on validation set

# %%
confusion_matrix_sklearn(tuned_decision_tree, X_val, y_val)
dt_val_perf = model_performance_classification_sklearn(tuned_decision_tree, X_val, y_val)
print("\nValidation Performance:")
print(dt_val_perf)
# Out:
# Validation Performance:
#    Accuracy    Recall  Precision        F1
# 0  0.733399  0.910615   0.746265  0.820289

# %% [markdown]
# ### Tuning XGBoost model with original Data

# %%
# %%time
# Choose the type of classifier
tuned_xgb = XGBClassifier(random_state=1, eval_metric="logloss")

# Grid of parameters to choose from
parameters = {
    "n_estimators": np.arange(50, 110, 25),
    "scale_pos_weight": [1, 2, 5],
    "subsample": [0.9, 1],
    "learning_rate": [0.01, 0.1, 0.05],
    "gamma": [1, 3]
}

# Type of scoring used to compare parameter combinations
acc_scorer = metrics.make_scorer(metrics.f1_score)

# Run the grid search
grid_obj = GridSearchCV(
    estimator=tuned_xgb,
    param_grid=parameters,
    scoring=acc_scorer,
    cv=5,
    n_jobs=-1
)

# Fit the grid search to the training data
grid_obj = grid_obj.fit(X_train, y_train)

# Set the classifier to the best combination of parameters
tuned_xgb = grid_obj.best_estimator_

# Fit the best algorithm to the training data
tuned_xgb.fit(X_train, y_train)
# Out:
# CPU times: total: 10.4 s
# Wall time: 2min 1s
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=3,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# Define the tuned XGBoost model
xgb_tuned_model = XGBClassifier(
    random_state=1,
    eval_metric='logloss',
    n_estimators=50,
    learning_rate=0.05,
    gamma=3
)

# Fit the model on training data
xgb_tuned_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=3,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ### Checking model performance on training set

# %%
confusion_matrix_sklearn(xgb_tuned_model, X_train, y_train)
xgb_tuned_model_train_perf = model_performance_classification_sklearn(xgb_tuned_model, X_train, y_train)
display(xgb_tuned_model_train_perf)
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.758171  0.896657   0.776118  0.832044

# %% [markdown]
# ### Checking model performance on validation set

# %%
confusion_matrix_sklearn(xgb_tuned_model, X_val, y_val)
xgb_tuned_model_val_perf = model_performance_classification_sklearn(xgb_tuned_model, X_val, y_val)
display(xgb_tuned_model_val_perf)
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.747348  0.889738   0.768606  0.824748

# %% [markdown]
# ### Tuning LGBM model with original Data

# %%
# 1. Define the base model
lgbm_model = LGBMClassifier(random_state=1)

# 2. Define the parameter grid
param_grid = {
    'n_estimators': [50, 75, 100],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'num_leaves': [15, 31, 63],
    'subsample': [0.8, 0.9, 1.0]
}

# 3. Define F1 scorer (or change to 'accuracy', 'roc_auc', etc.)
f1_scorer = metrics.make_scorer(metrics.f1_score)

# 4. Setup GridSearchCV
grid_search = GridSearchCV(
    estimator=lgbm_model,
    param_grid=param_grid,
    scoring=f1_scorer,
    cv=5,
    n_jobs=-1
)

# 5. Fit the model
grid_search.fit(X_train, y_train)

# 6. Output the best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation F1 score: {:.4f}".format(grid_search.best_score_))
# Out:
# Best parameters: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'num_leaves': 15, 'subsample': 0.8}
# Best cross-validation F1 score: 0.8252

# %%
# Refit the model with best parameters
tuned_lgbm = grid_search.best_estimator_
tuned_lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(learning_rate=0.01, max_depth=7, num_leaves=15, random_state=1,
#                subsample=0.8)

# %% [markdown]
# #### Checking model performance on training set

# %%
# Confusion Matrix
confusion_matrix_sklearn(tuned_lgbm, X_train, y_train)

# Classification report
lgbm_train_perf = model_performance_classification_sklearn(
    tuned_lgbm, X_train, y_train
)
lgbm_train_perf
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.743499  0.919502   0.751864  0.827276

# %% [markdown]
# #### Checking model performance on validation set

# %%
# Confusion Matrix
confusion_matrix_sklearn(tuned_lgbm, X_val, y_val)

# Classification report
lgbm_val_perf = model_performance_classification_sklearn(
    tuned_lgbm, X_val, y_val
)
lgbm_val_perf
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.740864  0.914437   0.751571  0.825043

# %% [markdown]
# ### Tuning Catboost model with original Data

# %%
# %%time

# Define the CatBoost model
Model = CatBoostClassifier(random_state=1, verbose=0)

# Parameter grid for CatBoost
param_grid = {
    "iterations": np.arange(50, 150, 25),
    "learning_rate": [0.01, 0.05, 0.1],
    "depth": [4, 6, 8, 10],
    "l2_leaf_reg": [1, 3, 5, 7, 9],
    "border_count": [32, 64, 128]
}

# F1 scorer
scorer = metrics.make_scorer(metrics.f1_score)

# RandomizedSearchCV
randomized_cv = RandomizedSearchCV(
    estimator=Model,
    param_distributions=param_grid,
    n_iter=50,
    scoring=scorer,
    cv=5,
    random_state=1,
    n_jobs=-1
)

# Fit the model
randomized_cv.fit(X_train, y_train)

# Print best parameters and F1 score
print("Best parameters are {} with CV score={:.4f}:".format(randomized_cv.best_params_, randomized_cv.best_score_))
# Out:
# Best parameters are {'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 50, 'depth': 6, 'border_count': 32} with CV score=0.8249:
# CPU times: total: 5.77 s
# Wall time: 5min 33s

# %%
# Create and train CatBoost model with best parameters from tuning
tuned_catboost = CatBoostClassifier(
    iterations=50,            # Number of boosting iterations
    learning_rate=0.05,        # Step size shrinkage
    l2_leaf_reg=1,            # L2 regularization coefficient
    depth=6,                  # Depth of the tree
    border_count=32,         # Number of splits for numerical features
    subsample=0.9,            # Subsample ratio for stochastic boosting
    random_state=1,           # For reproducibility
    verbose=0                 # Suppress training output
)

# Fit the model
tuned_catboost.fit(X_train, y_train)

# %%
catboost_train_perf = model_performance_classification_sklearn(
    tuned_catboost, X_train, y_train
)
print("CatBoost Training Performance:")
print(catboost_train_perf)
# Out:
# CatBoost Training Performance:
#    Accuracy    Recall  Precision        F1
# 0  0.751032  0.902147   0.766495  0.828807

# %%
catboost_val_perf = model_performance_classification_sklearn(
    tuned_catboost, X_val, y_val
)
print("\nCatBoost Validation Performance:")
print(catboost_val_perf)
# Out:
# CatBoost Validation Performance:
#    Accuracy    Recall  Precision        F1
# 0  0.744401  0.896207   0.762763  0.824118

# %% [markdown]
# # **Model Performance Improvement**

# %% [markdown]
# ## **Note**

# %% [markdown]
# 1. Sample parameter grids have been provided to do necessary hyperparameter tuning. These sample grids are expected to provide a balance between model performance improvement and execution time. One can extend/reduce the parameter grid based on execution time and system configuration.
#   - Please note that if the parameter grid is extended to improve the model performance further, the execution time will increase
# 2. The models chosen in this notebook are based on test runs. One can update the best models as obtained upon code execution and tune them for best performance.
#
# - For Gradient Boosting:
#
# ```
# param_grid = {
#     "init": [AdaBoostClassifier(random_state=1),DecisionTreeClassifier(random_state=1)],
#     "n_estimators": np.arange(50,110,25),
#     "learning_rate": [0.01,0.1,0.05],
#     "subsample":[0.7,0.9],
#     "max_features":[0.5,0.7,1],
# }
# ```
#
# - For Adaboost:
#
# ```
# param_grid = {
#     "n_estimators": np.arange(50,110,25),
#     "learning_rate": [0.01,0.1,0.05],
#     "base_estimator": [
#         DecisionTreeClassifier(max_depth=2, random_state=1),
#         DecisionTreeClassifier(max_depth=3, random_state=1),
#     ],
# }
# ```
#
# - For Bagging Classifier:
#
# ```
# param_grid = {
#     'max_samples': [0.8,0.9,1],
#     'max_features': [0.7,0.8,0.9],
#     'n_estimators' : [30,50,70],
# }
# ```
# - For Random Forest:
#
# ```
# param_grid = {
#     "n_estimators": [50,110,25],
#     "min_samples_leaf": np.arange(1, 4),
#     "max_features": [np.arange(0.3, 0.6, 0.1),'sqrt'],
#     "max_samples": np.arange(0.4, 0.7, 0.1)
# }
# ```
#
# - For Decision Trees:
#
# ```
# param_grid = {
#     'max_depth': np.arange(2,6),
#     'min_samples_leaf': [1, 4, 7],
#     'max_leaf_nodes' : [10, 15],
#     'min_impurity_decrease': [0.0001,0.001]
# }
# ```
#
# - For XGBoost:
#
# ```
# param_grid={'n_estimators':np.arange(50,110,25),
#             'scale_pos_weight':[1,2,5],
#             'learning_rate':[0.01,0.1,0.05],
#             'gamma':[1,3],
#             'subsample':[0.7,0.9]
# }
# ```

# %% [markdown]
# # **Model Comparison and Final Model Selection**

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [  adb_train.T,
        adb_train_over.T,
        adb_train_un.T,
        gbm1_train.T,
        gbm1_train_over.T,
        gbm1_train_un.T,
        tuned_rf_model_train_perf.T,
        dt_train_perf.T,
        xgb_tuned_model_train_perf.T,
        lgbm_val_perf.T,
        catboost_train_perf.T
 
    ],
    axis=1,
)
models_train_comp_df.columns = [
    "AdaBoostClassifier model with original data",
    "AdaBoostClassifier model with oversampling data",
    "AdaBoostClassifier model with undersampling data",
    "Gradient Boosting with original data",
    "Gradient Boostingl with oversampling data",
    "Gradient Boosting with undersampling data",
    "Random Forest model with original Data",
    "Decision Treeswith original Data",
    "XGBost original Data",
    "LGBM model with original Data",
    "Catboost model with original Data",
]

print("Training performance comparison:")
models_train_comp_df
# Out:
# Training performance comparison:
#            AdaBoostClassifier model with original data  \
# Accuracy                                      0.746840
# Recall                                        0.900775
# Precision                                     0.763040
# F1                                            0.826206
#
#            AdaBoostClassifier model with oversampling data  \
# Accuracy                                          0.799980
# Recall                                            0.817629
# Precision                                         0.789753
# F1                                                0.803449
#
#            AdaBoostClassifier model with undersampling data  \
# Accuracy                                           0.711425
# Recall                                             0.752565
# Precision                                          0.695351
# F1                                                 0.722828
#
# ...

# %%
# Validation performance comparison

models_train_comp_df = pd.concat(
    [   adb_val.T,
        adb_val_over.T,
        adb_val_un.T,
        gbm1_val.T,
        gbm1_val_over.T,
        gbm1_val_un.T,
        bagging_val.T,
        tuned_rf_model_val_perf.T,    
         dt_val_perf.T,
        xgb_tuned_model_val_perf.T,
        lgbm_val_perf.T,
        catboost_val_perf.T
    ], axis=1,
)
models_train_comp_df.columns = [
    "AdaBoostClassifier model with original data",
    "AdaBoostClassifier model with oversampling data",
    "AdaBoostClassifier model with undersampling data",
    "Gradient Boosting with original data",
    "Gradient Boostingl with oversampling data",
    "Gradient Boosting with undersampling data",
    "Bagging Classifier model with original Data",
    "Random Forest model with original Data",
    "Decision Treeswith original Data",
    "XGBost original Data",
    "LGBM model with original Data",
    "Catboost model with original Data",
]
print("Validation performance comparison:")
models_train_comp_df
# Out:
# Validation performance comparison:
#            AdaBoostClassifier model with original data  \
# Accuracy                                      0.744204
# Recall                                        0.898853
# Precision                                     0.761395
# F1                                            0.824434
#
#            AdaBoostClassifier model with oversampling data  \
# Accuracy                                          0.734381
# Recall                                            0.812702
# Precision                                         0.794481
# F1                                                0.803488
#
#            AdaBoostClassifier model with undersampling data  \
# Accuracy                                           0.711984
# Recall                                             0.743605
# Precision                                          0.809798
# F1                                                 0.775291
#
# ...

# %% [markdown]
# LGBM model with original Data model has generalised performance (0.825043), so let's consider it as the best model.

# %%
# Let's check the performance on test set
lgbm_test = model_performance_classification_sklearn(
    tuned_lgbm, X_test, y_test
)
lgbm_test
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.738507  0.911791   0.750484  0.823311

# %% [markdown]
# Also XGBost original Data has high performance (0.824748)

# %%
xgb_test = model_performance_classification_sklearn(xgb_tuned_model, X_test, y_test)
display(xgb_test)
# Out:
#    Accuracy   Recall  Precision        F1
# 0  0.751277  0.88915   0.772809  0.826907

# %% [markdown]
# So xgboost is better on test data

# %% [markdown]
# ### Feature Importance

# %%
feature_names = X_train.columns
importances = tuned_lgbm.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(12, 12))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], color="violet", align="center")
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# # **Actionable Insights and Recommendations**

# %% [markdown]
# ## Model Performance (XGBoost Classifier on Test Set)
#
# | Metric     | Score    |
# |------------|----------|
# | **Accuracy**   | 0.751    |
# | **Recall**     | 0.889    |
# | **Precision**  | 0.773    |
# | **F1 Score**   | 0.827    |

# %% [markdown]
# ___

# %% [markdown]
# - **High Recall (0.889)**: Most certified applications are correctly identified.
# - **Strong F1 Score (0.827)**: Balanced performance between precision and recall.
# - **Good Accuracy (0.75)** and **Precision (0.77)** support reliable classification of applicants and help minimize false approvals or denials.
#
# Top features influencing visa approval:
#
# 1. `education_of_employee_Master's`
# 2. `education_of_employee_Doctorate`
# 3. `has_job_experience_Y`
# 4. `continent_Europe`
# 5. `region_of_employment_Midwest`
# 6. `region_of_employment_South`
# 7. `education_of_employee_High School`
# 8. `unit_of_wage_Year`
# 9. `continent_North America`
# 10. `full_time_position_Y`
#
# ## key insights
#
# - **Education level** is a critical factor — higher degrees significantly improve chances of certification.
# - **Prior job experience** is a strong positive predictor for visa approval.
# - **Geographic factors**, including both the employee’s continent and U.S. employment region, affect outcomes.
# - **Full-time positions** and **higher prevailing wages** improve likelihood of certification.
#
# ## Recomendations
#
# Recommendations
#
# ### 1. Automate Screening for OFLC
#
# - Use the trained XGBoost model to **pre-screen applications** likely to be approved.
# - **Flag high-risk applications** (likely to be denied) for additional human review.
#
# ### 2. Guidance for Applicants and Employers
#
# - Encourage applicants to pursue **higher education** (Master’s or Doctorate).
# - Prioritize candidates with **previous work experience**.
# - Consider employment offers in regions with **higher approval rates** (e.g., Midwest, South).
# - Ensure **competitive wage offerings** to meet or exceed prevailing wage levels.
#
# ### 3. Improve Policy and Business Processes
#
# - OFLC can use these insights to build **data-driven immigration strategies**.
# - Visa consultants (like EasyVisa) can **advise clients** on application improvements using model feedback.
